# %%
import pandas as pd
import os
import numpy as np
import scipy.stats as sts
import shutil
from os import listdir

labels=pd.read_csv("Datasets/labels.csv")
labels.head()
# Out:
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
breeds= sts.itemfreq(labels['breed'])
breeds=sorted(breeds, key=lambda x: -x[1])
dir_top= "Dog Breed/train_top/"
dir_actual= "Dog Breed/train/"

# %%
breeds[0:15]
# Out:
# [array(['scottish_deerhound', 126], dtype=object),
#  array(['maltese_dog', 117], dtype=object),
#  array(['afghan_hound', 116], dtype=object),
#  array(['entlebucher', 115], dtype=object),
#  array(['bernese_mountain_dog', 114], dtype=object),
#  array(['shih-tzu', 112], dtype=object),
#  array(['great_pyrenees', 111], dtype=object),
#  array(['pomeranian', 111], dtype=object),
#  array(['basenji', 110], dtype=object),
#  array(['samoyed', 109], dtype=object),
#  array(['airedale', 107], dtype=object),
#  array(['tibetan_terrier', 107], dtype=object),
#  array(['cairn', 106], dtype=object),
#  array(['leonberg', 106], dtype=object),
#  array(['beagle', 105], dtype=object)]

# %%
def det_ids(breeds_completo, clases):
    breeds_sub=breeds_completo[0:clases]
    #os.mkdir(dir_top)
    razas_top= []
    for reg in breeds_sub:
        razas_top.append(reg[0])
        
    for reg in listdir(dir_actual):        
        if reg in razas_top:
            cont=1
            for imagen in listdir(dir_actual+reg):
                try:
                    os.mkdir(dir_top+"ejemplos_train_"+str(clases)+'/')
                    os.mkdir(dir_top+"ejemplos_val_"+str(clases)+'/')
                   #os.mkdir(dir_top+"ejemplos_train_"+str(clases)+'/'+reg+'/')
                    print ("listo car")
                except Exception as e:
                        #print (e)
                        pass
                try:
                    #os.mkdir(dir_top+"ejemplos_train_"+str(clases)+'/')
                    os.mkdir(dir_top+"ejemplos_train_"+str(clases)+'/'+reg+'/')
                    os.mkdir(dir_top+"ejemplos_val_"+str(clases)+'/'+reg+'/')
                    print ("listo raza")
                except Exception as e:
                        #print (e)
                        pass
                if cont<=int(len(listdir(dir_actual+reg))*0.8):
                    shutil.copy(dir_actual+reg+'/'+imagen, dir_top+"ejemplos_train_"+str(clases)+'/'+reg+'/'+imagen)
                else:
                    print ("ESDEfv")
                    shutil.copy(dir_actual+reg+'/'+imagen, dir_top+"ejemplos_val_"+str(clases)+'/'+reg+'/'+imagen)
                    
                cont+=1
        
    return

# %% [markdown]
# #### Crea los directorios de entrenamiento segun las K clases de mayor número de eje. training

# %%
det_ids(breeds, 5)
det_ids(breeds, 10)
det_ids(breeds, 15)
det_ids(breeds, 20)
det_ids(breeds, 25)
# Out:
# listo car
# listo raza
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# listo raza
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# listo raza
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# listo raza
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# listo raza
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# ESDEfv
# listo car
# listo raza
# ESDEfv
# ESDEfv
# ...

# %% [markdown]
# ### DogImages

# %%
dir_top= "Dog Breed/train_top/"
dir_actual_DI= "DogImages/dogImages/train/"
dir_actual_val_DI= "DogImages/dogImages/valid/"

# %%
def det_ids_DI(breeds_completo, clases):
    breeds_sub=breeds_completo[0:clases]
    #os.mkdir(dir_top)
    razas_top= []
    for reg in breeds_sub:
        razas_top.append(reg[0])
        
    for reg in listdir(dir_actual_DI): 
        reg_lower=reg[4::]
        reg_lower=reg_lower.lower()        
        print (reg_lower)
        if reg_lower in razas_top:
            #cont=1
            #for imagen in listdir(dir_actual_DI+reg):
                try:
                    os.mkdir(dir_top+"ejemplos_train_DI_"+str(clases)+'/')
                    os.mkdir(dir_top+"ejemplos_val_DI_"+str(clases)+'/')
                   #os.mkdir(dir_top+"ejemplos_train_"+str(clases)+'/'+reg+'/')
                    print ("listo car")
                except Exception as e:
                        #print (e)
                        pass
                #try:
                 #   #os.mkdir(dir_top+"ejemplos_train_"+str(clases)+'/')
                    #os.mkdir(dir_top+"ejemplos_train_DI_"+str(clases)+'/'+reg_lower+'/')
                    #os.mkdir(dir_top+"ejemplos_val_DI_"+str(clases)+'/'+reg_lower+'/')
                #    print ("listo raza")
                #except Exception as e:
                    #print (e)
                #    pass
                #if cont<=int(len(listdir(dir_actual+reg))*0.8):
                
                shutil.copytree(dir_actual_DI+reg, dir_top+"ejemplos_train_DI_"+str(clases)+'/'+reg_lower)
                shutil.copytree(dir_actual_val_DI+reg, dir_top+"ejemplos_val_DI_"+str(clases)+'/'+reg_lower)
            
    return

# %%
det_ids_DI(breeds, 5)
det_ids_DI(breeds, 10)
det_ids_DI(breeds, 15)
det_ids_DI(breeds, 20)
det_ids_DI(breeds, 25)
# Out:
# pharaoh_hound
# gordon_setter
# petit_basset_griffon_vendeen
# clumber_spaniel
# nova_scotia_duck_tolling_retriever
# chinese_crested
# bichon_frise
# english_setter
# cane_corso
# english_springer_spaniel
# pekingese
# lhasa_apso
# norwegian_buhund
# old_english_sheepdog
# smooth_fox_terrier
# greater_swiss_mountain_dog
# basset_hound
# borzoi
# papillon
# flat-coated_retriever
# bouvier_des_flandres
# cocker_spaniel
# german_pinscher
# finnish_spitz
# neapolitan_mastiff
# border_terrier
# french_bulldog
# irish_setter
# australian_terrier
# leonberger
# great_dane
# pembroke_welsh_corgi
# german_shorthaired_pointer
# bloodhound
# maltese
# border_collie
# irish_red_and_white_setter
# airedale_terrier
# irish_terrier
# black_and_tan_coonhound
# glen_of_imaal_terrier
# beagle
# tibetan_mastiff
# field_spaniel
# newfoundland
# japanese_chin
# akita
# dalmatian
# belgian_tervuren
# dogue_de_bordeaux
# irish_wolfhound
# american_eskimo_dog
# poodle
# norfolk_terrier
# norwich_terrier
# ...
